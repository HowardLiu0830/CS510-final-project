# %% [markdown]
# # Smoke test
# Run a single end-to-end pipeline call in offline mode.

# %%
from research_trail.agents.graph import compile_graph
g = compile_graph()
state = g.invoke({"query": "graph neural networks for drug discovery"})
state
